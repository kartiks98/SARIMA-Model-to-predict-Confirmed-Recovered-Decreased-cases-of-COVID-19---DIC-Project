# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
import os

# %%
# cwd = os.getcwd()
# cwd

# %%
# raw_csv_data = pd.read_csv(cwd + '\TG.csv')
raw_csv_data = pd.read_csv('TG.csv')
df=raw_csv_data.copy()

# %%
para = 'Confirmed'

# %%
df.Date.describe()
# Out:
# count           115
# unique          115
# top       08-Jun-20
# freq              1
# Name: Date, dtype: object

# %%
df
# Out:
#           Date  Confirmed  Recovered  Decreased
# 0    14-Mar-20          1          0          0
# 1    15-Mar-20          2          1          0
# 2    16-Mar-20          1          0          0
# 3    17-Mar-20          1          0          0
# 4    18-Mar-20          8          0          0
# ..         ...        ...        ...        ...
# 110  02-Jul-20       1213        987          8
# 111  03-Jul-20       1892       1126          8
# 112  04-Jul-20       1850       1342          5
# 113  05-Jul-20       1590       1166          7
# 114  06-Jul-20       1831       2078         11
#
# [115 rows x 4 columns]

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date  Confirmed  Recovered  Decreased
# 0 2020-03-14          1          0          0
# 1 2020-03-15          2          1          0
# 2 2020-03-16          1          0          0
# 3 2020-03-17          1          0          0
# 4 2020-03-18          8          0          0

# %%
df
# Out:
#           Date  Confirmed  Recovered  Decreased
# 0   2020-03-14          1          0          0
# 1   2020-03-15          2          1          0
# 2   2020-03-16          1          0          0
# 3   2020-03-17          1          0          0
# 4   2020-03-18          8          0          0
# ..         ...        ...        ...        ...
# 110 2020-07-02       1213        987          8
# 111 2020-07-03       1892       1126          8
# 112 2020-07-04       1850       1342          5
# 113 2020-07-05       1590       1166          7
# 114 2020-07-06       1831       2078         11
#
# [115 rows x 4 columns]

# %%
df.set_index('Date', inplace=True)
df.index.freq = 'D'

# %%
df
# Out:
#             Confirmed  Recovered  Decreased
# Date
# 2020-03-14          1          0          0
# 2020-03-15          2          1          0
# 2020-03-16          1          0          0
# 2020-03-17          1          0          0
# 2020-03-18          8          0          0
# ...               ...        ...        ...
# 2020-07-02       1213        987          8
# 2020-07-03       1892       1126          8
# 2020-07-04       1850       1342          5
# 2020-07-05       1590       1166          7
# 2020-07-06       1831       2078         11
#
# [115 rows x 3 columns]

# %%
# df.Date.describe()

# %%
df
# Out:
#             Confirmed  Recovered  Decreased
# Date
# 2020-03-14          1          0          0
# 2020-03-15          2          1          0
# 2020-03-16          1          0          0
# 2020-03-17          1          0          0
# 2020-03-18          8          0          0
# ...               ...        ...        ...
# 2020-07-02       1213        987          8
# 2020-07-03       1892       1126          8
# 2020-07-04       1850       1342          5
# 2020-07-05       1590       1166          7
# 2020-07-06       1831       2078         11
#
# [115 rows x 3 columns]

# %%
df[para].plot(figsize=(12,5));

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df[para])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        6.948175
# p-value                   1.000000
# # lags used              10.000000
# # observations          104.000000
# critical value (1%)      -3.494850
# critical value (5%)      -2.889758
# critical value (10%)     -2.581822
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
result = seasonal_decompose(df[para])
result.plot();

# %%
from statsmodels.tsa.statespace.tools import diff
df['d1'] = diff(df[para],k_diff=2)

# %%
adf_test(df['d1'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -6.126422e+00
# p-value                 8.607278e-08
# # lags used             1.100000e+01
# # observations          1.010000e+02
# critical value (1%)    -3.496818e+00
# critical value (5%)    -2.890611e+00
# critical value (10%)   -2.582277e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
# stepwise_fit = auto_arima(df[para], start_p=0, start_q=0,
#                           max_p=4, max_q=4,
#                           seasonal=False,
#                           d=None, trace=True,
#                           error_action='ignore',   # we don't want to know if an order does not work
#                           suppress_warnings=True,  # we don't want convergence warnings
#                           stepwise=True)           # set to stepwise

# stepwise_fit.summary()

stepwise_fit = auto_arima(df[para], start_p=0, start_q=0,
                          max_p=4, max_q=4,
                          seasonal=True,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True,           # set to stepwise
                         frequency=19)

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(0,2,0)x(0,0,0,0) [intercept=True]; AIC=1395.824, BIC=1401.278, Time=0.011 seconds
# Fit ARIMA(1,2,0)x(0,0,0,0) [intercept=True]; AIC=1383.014, BIC=1391.196, Time=0.053 seconds
# Fit ARIMA(0,2,1)x(0,0,0,0) [intercept=True]; AIC=1327.614, BIC=1335.796, Time=0.080 seconds
# Near non-invertible roots for order (0, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(0,2,0)x(0,0,0,0) [intercept=False]; AIC=1393.863, BIC=1396.590, Time=0.007 seconds
# Fit ARIMA(2,2,0)x(0,0,0,0) [intercept=True]; AIC=1353.522, BIC=1364.432, Time=0.063 seconds
# Fit ARIMA(3,2,0)x(0,0,0,0) [intercept=True]; AIC=1341.383, BIC=1355.020, Time=0.108 seconds
# Fit ARIMA(4,2,0)x(0,0,0,0) [intercept=True]; AIC=1339.807, BIC=1356.171, Time=0.142 seconds
# Fit ARIMA(4,2,1)x(0,0,0,0) [intercept=True]; AIC=1325.251, BIC=1344.342, Time=0.297 seconds
# Fit ARIMA(3,2,1)x(0,0,0,0) [intercept=True]; AIC=1323.432, BIC=1339.796, Time=0.220 seconds
# Fit ARIMA(2,2,1)x(0,0,0,0) [intercept=True]; AIC=1321.437, BIC=1335.074, Time=0.215 seconds
# Fit ARIMA(1,2,1)x(0,0,0,0) [intercept=True]; AIC=1329.593, BIC=1340.502, Time=0.129 seconds
# Near non-invertible roots for order (1, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA(2,2,2)x(0,0,0,0) [intercept=True]; AIC=1323.431, BIC=1339.795, Time=0.267 seconds
# Fit ARIMA(1,2,2)x(0,0,0,0) [intercept=True]; AIC=1329.097, BIC=1342.734, Time=0.215 seconds
# Near non-invertible roots for order (1, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(3,2,2)x(0,0,0,0) [intercept=True]; AIC=1325.087, BIC=1344.179, Time=0.513 seconds
# Near non-invertible roots for order (3, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 2.334 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  115
# Model:               SARIMAX(2, 2, 1)   Log Likelihood                -655.719
# Date:                Thu, 16 Jul 2020   AIC                           1321.437
# Time:                        00:21:59   BIC                           1335.074
# Sample:                             0   HQIC                          1326.971
#                                 - 115
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.1309      1.031      1.097      0.273      -0.890       3.152
# ar.L1         -0.0048      0.075     -0.064      0.949      -0.152       0.143
# ar.L2         -0.3532      0.081     -4.366      0.000      -0.512      -0.195
# ma.L1         -0.9165      0.066    -13.951      0.000      -1.045      -0.788
# sigma2      6278.2404    366.275     17.141      0.000    5560.356    6996.125
# ===================================================================================
# Ljung-Box (Q):                       22.93   Jarque-Bera (JB):              6326.72
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):              26.59   Skew:                             4.63
# Prob(H) (two-sided):                  0.00   Kurtosis:                        38.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train = df.iloc[:104]
test = df.iloc[104:111]

# %%
# from statsmodels.tsa.arima_model import ARMA,ARMAResults,ARIMA,ARIMAResults
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# model = ARIMA(train[para],order=(2,2,1))
model = SARIMAX(train[para],order=(2,2,1),seasonal_order=(2,2,1,19))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Confirmed   No. Observations:                  104
# Model:             SARIMAX(2, 2, 1)x(2, 2, 1, 19)   Log Likelihood                -356.334
# Date:                            Thu, 16 Jul 2020   AIC                            726.669
# Time:                                    00:22:08   BIC                            741.781
# Sample:                                03-14-2020   HQIC                           732.622
#                                      - 06-25-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0238      0.150     -0.159      0.874      -0.317       0.270
# ar.L2          0.2248      0.168      1.339      0.181      -0.104       0.554
# ma.L1         -0.9982      3.121     -0.320      0.749      -7.116       5.119
# ar.S.L19      -0.5516      1.271     -0.434      0.664      -3.043       1.940
# ar.S.L38       0.0717      1.018      0.070      0.944      -1.923       2.066
# ma.S.L19      -0.5963      1.532     -0.389      0.697      -3.599       2.406
# sigma2      2486.1573   7417.503      0.335      0.737   -1.21e+04     1.7e+04
# ===================================================================================
# Ljung-Box (Q):                       28.63   Jarque-Bera (JB):                 4.32
# Prob(Q):                              0.91   Prob(JB):                         0.12
# Heteroskedasticity (H):               3.53   Skew:                             0.63
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Obtain predicted values
# start=len(train)
# end=len(train)+len(test)-1

start=104
end=110

# predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('ARIMA(2,2,1) Predictions')
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('SARIMAX(2,2,1,19) Predictions')

# df['forecast'] = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('ARIMA(2,2,1) Predictions')

# %%
# Obtain predicted values
ax = test[para].plot(legend=True,figsize=(12,6))
predictions.plot(legend=True)
# df['forecast'].plot(legend=True)
ax.autoscale(axis='x',tight=True)

# %%
# # from statsmodels.tools.eval_measures import rmse
# from statsmodels.tools.eval_measures import mse

# error = mse(test[para], predictions)
# # print(f'ARIMA(2,2,1) RMSE Error: {error:11.10}')
# # print(f'ARIMA(2,2,1) MSE Error: {error:11.10}')
# print(f'SARIMAX(2,2,1,3) MSE Error: {error:11.10}')

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(test[para], predictions)
MAE
# Out:
# 84.99040413782316

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# per_MAPE = (MAPE/sum(test[para]))*100
per_MAPE = mean_absolute_percentage_error(test[para], predictions)
print(per_MAPE,'%')
# Out:
# 8.091759376646195 %

# %%
type(predictions)
# Out:
# pandas.core.series.Series

# %%
df['forecast'] = predictions
df
# Out:
#             Confirmed  Recovered  Decreased     d1     forecast
# Date
# 2020-03-14          1          0          0    NaN          NaN
# 2020-03-15          2          1          0    NaN          NaN
# 2020-03-16          1          0          0   -2.0          NaN
# 2020-03-17          1          0          0    1.0          NaN
# 2020-03-18          8          0          0    7.0          NaN
# ...               ...        ...        ...    ...          ...
# 2020-07-02       1213        987          8  122.0  1120.273052
# 2020-07-03       1892       1126          8  484.0          NaN
# 2020-07-04       1850       1342          5 -721.0          NaN
# 2020-07-05       1590       1166          7 -218.0          NaN
# 2020-07-06       1831       2078         11  501.0          NaN
#
# [115 rows x 5 columns]

# %%
dictt = {f'{para}':test[para],f'Predicted_{para}':predictions}
dictt
# Out:
# {'Confirmed': Date
#  2020-06-26     985
#  2020-06-27    1087
#  2020-06-28     983
#  2020-06-29     975
#  2020-06-30     945
#  2020-07-01    1018
#  2020-07-02    1213
#  Freq: D, Name: Confirmed, dtype: int64,
#  'Predicted_Confirmed': 2020-06-26     891.384322
#  2020-06-27     841.514656
#  2020-06-28     940.780785
#  2020-06-29     991.273602
#  2020-06-30    1033.261360
#  2020-07-01    1001.649318
#  2020-07-02    1120.273052
#  Freq: D, Name: SARIMAX(2,2,1,19) Predictions, dtype: float64}

# %%
predicted_df = pd.DataFrame(dictt)
predicted_df
# Out:
#             Confirmed  Predicted_Confirmed
# Date
# 2020-06-26        985           891.384322
# 2020-06-27       1087           841.514656
# 2020-06-28        983           940.780785
# 2020-06-29        975           991.273602
# 2020-06-30        945          1033.261360
# 2020-07-01       1018          1001.649318
# 2020-07-02       1213          1120.273052

# %%
predicted_df.to_csv('Predicted_TG.csv')
# predicted_csv = pd.read_csv('Predicted_TG.csv')

# predicted_csv.Date = pd.to_datetime(predicted_csv.Date)
# predicted_csv.set_index('Date', inplace=True)
# predicted_csv.index.freq = 'D'
# # print(predicted_csv)
# # predicted_csv = pd.concat([predicted_csv,predicted_df],axis=1,ignore_index=True)
# predicted_csv = pd.merge(predicted_csv, predicted_df, left_index=True, right_index=True, how='outer')
# # predicted_csv = predicted_csv.join(predicted_df, how='outer')
# print(predicted_csv)
# predicted_csv.to_csv('Predicted_TG.csv')

# %%
from pandas.tseries.offsets import DateOffset
import datetime
future_dates=[datetime.datetime(2020, 7, 7)+ DateOffset(n=x)for x in range(0,25)]

# %%
future_datest_df=pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Confirmed Recovered Decreased   d1 forecast
# 2020-07-27       NaN       NaN       NaN  NaN      NaN
# 2020-07-28       NaN       NaN       NaN  NaN      NaN
# 2020-07-29       NaN       NaN       NaN  NaN      NaN
# 2020-07-30       NaN       NaN       NaN  NaN      NaN
# 2020-07-31       NaN       NaN       NaN  NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])
future_df = future_df.drop("d1", axis=1)
future_df
# Out:
#            Confirmed Recovered Decreased  forecast
# 2020-03-14         1         0         0       NaN
# 2020-03-15         2         1         0       NaN
# 2020-03-16         1         0         0       NaN
# 2020-03-17         1         0         0       NaN
# 2020-03-18         8         0         0       NaN
# ...              ...       ...       ...       ...
# 2020-07-27       NaN       NaN       NaN       NaN
# 2020-07-28       NaN       NaN       NaN       NaN
# 2020-07-29       NaN       NaN       NaN       NaN
# 2020-07-30       NaN       NaN       NaN       NaN
# 2020-07-31       NaN       NaN       NaN       NaN
#
# [140 rows x 4 columns]

# %%
future_df[[para, 'forecast']]
# Out:
#            Confirmed  forecast
# 2020-03-14         1       NaN
# 2020-03-15         2       NaN
# 2020-03-16         1       NaN
# 2020-03-17         1       NaN
# 2020-03-18         8       NaN
# ...              ...       ...
# 2020-07-27       NaN       NaN
# 2020-07-28       NaN       NaN
# 2020-07-29       NaN       NaN
# 2020-07-30       NaN       NaN
# 2020-07-31       NaN       NaN
#
# [140 rows x 2 columns]

# %%
# future_df['forecast'] = results.predict(start = 115, end = 139, dynamic= True)
future_pred = results.predict(start=115, end=139, dynamic=False, typ='levels')

# %%
future_df['forecast'] = future_pred

# %%
future_df[[para, 'forecast']].plot(figsize=(12, 8))

# %%
dicttt = {f'Future_Predicted_{para}':future_pred}
dicttt
# Out:
# {'Future_Predicted_Confirmed': 2020-07-07    1312.170682
#  2020-07-08    1561.891244
#  2020-07-09    1558.475771
#  2020-07-10    1748.087863
#  2020-07-11    1919.183430
#  2020-07-12    1946.009568
#  2020-07-13    2000.145139
#  2020-07-14    2095.202502
#  2020-07-15    2059.587023
#  2020-07-16    2004.710887
#  2020-07-17    2169.480354
#  2020-07-18    2242.432883
#  2020-07-19    2324.592163
#  2020-07-20    2291.978276
#  2020-07-21    2474.485417
#  2020-07-22    2516.503890
#  2020-07-23    2532.137499
#  2020-07-24    2573.558353
#  2020-07-25    2708.926647
#  2020-07-26    2831.662182
#  2020-07-27    3142.686664
#  2020-07-28    3230.718596
#  2020-07-29    3546.988858
#  2020-07-30    3810.788125
#  2020-07-31    3865.835491
#  Freq: D, dtype: float64}

# %%
future_predicted_df = pd.DataFrame(dicttt)
future_predicted_df
# Out:
#             Future_Predicted_Confirmed
# 2020-07-07                 1312.170682
# 2020-07-08                 1561.891244
# 2020-07-09                 1558.475771
# 2020-07-10                 1748.087863
# 2020-07-11                 1919.183430
# 2020-07-12                 1946.009568
# 2020-07-13                 2000.145139
# 2020-07-14                 2095.202502
# 2020-07-15                 2059.587023
# 2020-07-16                 2004.710887
# 2020-07-17                 2169.480354
# 2020-07-18                 2242.432883
# 2020-07-19                 2324.592163
# 2020-07-20                 2291.978276
# 2020-07-21                 2474.485417
# 2020-07-22                 2516.503890
# 2020-07-23                 2532.137499
# 2020-07-24                 2573.558353
# 2020-07-25                 2708.926647
# 2020-07-26                 2831.662182
# 2020-07-27                 3142.686664
# 2020-07-28                 3230.718596
# 2020-07-29                 3546.988858
# 2020-07-30                 3810.788125
# 2020-07-31                 3865.835491

# %%
future_predicted_df.index.names = ['Date']
future_predicted_df.index.freq = 'D'
future_predicted_df.to_csv('Future_Predicted_TG.csv')

# future_predicted_csv = pd.read_csv('Future_Predicted_TG.csv')

# future_predicted_csv.Date = pd.to_datetime(future_predicted_csv.Date)
# future_predicted_csv.set_index('Date', inplace=True)
# future_predicted_csv.index.freq = 'D'
# # print(future_predicted_csv)
# # future_predicted_csv = pd.concat([future_predicted_csv,future_predicted_df],axis=1,ignore_index=True)
# future_predicted_csv = pd.merge(future_predicted_csv, future_predicted_df, left_index=True, right_index=True, how='outer')
# # predicted_csv = predicted_csv.join(predicted_df, how='outer')
# print(future_predicted_csv)
# future_predicted_csv.to_csv('Future_Predicted_TG.csv')
