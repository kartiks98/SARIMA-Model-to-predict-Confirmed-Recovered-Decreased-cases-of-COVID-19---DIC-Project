# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
import os

# %%
# cwd = os.getcwd()
# cwd

# %%
# raw_csv_data = pd.read_csv(cwd + '\TG.csv')
raw_csv_data = pd.read_csv('KA.csv')
df=raw_csv_data.copy()

# %%
para = 'Confirmed'

# %%
df.Date.describe()
# Out:
# count           115
# unique          115
# top       26-Jun-20
# freq              1
# Name: Date, dtype: object

# %%
df
# Out:
#           Date  Confirmed  Recovered  Deceased
# 0    14-Mar-20          6          0         1
# 1    15-Mar-20          0          0         0
# 2    16-Mar-20          1          0         0
# 3    17-Mar-20          2          0         0
# 4    18-Mar-20          5          0         0
# ..         ...        ...        ...       ...
# 110  02-Jul-20       1502        271        19
# 111  03-Jul-20       1694        471        21
# 112  04-Jul-20       1839        439        42
# 113  05-Jul-20       1925        603        37
# 114  06-Jul-20       1843        680        30
#
# [115 rows x 4 columns]

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date  Confirmed  Recovered  Deceased
# 0 2020-03-14          6          0         1
# 1 2020-03-15          0          0         0
# 2 2020-03-16          1          0         0
# 3 2020-03-17          2          0         0
# 4 2020-03-18          5          0         0

# %%
df
# Out:
#           Date  Confirmed  Recovered  Deceased
# 0   2020-03-14          6          0         1
# 1   2020-03-15          0          0         0
# 2   2020-03-16          1          0         0
# 3   2020-03-17          2          0         0
# 4   2020-03-18          5          0         0
# ..         ...        ...        ...       ...
# 110 2020-07-02       1502        271        19
# 111 2020-07-03       1694        471        21
# 112 2020-07-04       1839        439        42
# 113 2020-07-05       1925        603        37
# 114 2020-07-06       1843        680        30
#
# [115 rows x 4 columns]

# %%
df.set_index('Date', inplace=True)
df.index.freq = 'D'

# %%
df
# Out:
#             Confirmed  Recovered  Deceased
# Date
# 2020-03-14          6          0         1
# 2020-03-15          0          0         0
# 2020-03-16          1          0         0
# 2020-03-17          2          0         0
# 2020-03-18          5          0         0
# ...               ...        ...       ...
# 2020-07-02       1502        271        19
# 2020-07-03       1694        471        21
# 2020-07-04       1839        439        42
# 2020-07-05       1925        603        37
# 2020-07-06       1843        680        30
#
# [115 rows x 3 columns]

# %%
# df.Date.describe()

# %%
df
# Out:
#             Confirmed  Recovered  Deceased
# Date
# 2020-03-14          6          0         1
# 2020-03-15          0          0         0
# 2020-03-16          1          0         0
# 2020-03-17          2          0         0
# 2020-03-18          5          0         0
# ...               ...        ...       ...
# 2020-07-02       1502        271        19
# 2020-07-03       1694        471        21
# 2020-07-04       1839        439        42
# 2020-07-05       1925        603        37
# 2020-07-06       1843        680        30
#
# [115 rows x 3 columns]

# %%
df[para].plot(figsize=(12,5));

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df[para])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        1.839840
# p-value                   0.998425
# # lags used              11.000000
# # observations          103.000000
# critical value (1%)      -3.495493
# critical value (5%)      -2.890037
# critical value (10%)     -2.581971
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
result = seasonal_decompose(df[para])
result.plot();

# %%
from statsmodels.tsa.statespace.tools import diff
df['d1'] = diff(df[para],k_diff=2)

# %%
adf_test(df['d1'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -5.831626e+00
# p-value                 3.962755e-07
# # lags used             7.000000e+00
# # observations          1.050000e+02
# critical value (1%)    -3.494220e+00
# critical value (5%)    -2.889485e+00
# critical value (10%)   -2.581676e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
# stepwise_fit = auto_arima(df[para], start_p=0, start_q=0,
#                           max_p=4, max_q=4,
#                           seasonal=False,
#                           d=None, trace=True,
#                           error_action='ignore',   # we don't want to know if an order does not work
#                           suppress_warnings=True,  # we don't want convergence warnings
#                           stepwise=True)           # set to stepwise

# stepwise_fit.summary()

stepwise_fit = auto_arima(df[para], start_p=0, start_q=0,
                          max_p=4, max_q=4,
                          seasonal=True,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True,           # set to stepwise
                         frequency=15)

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(0,2,0)x(0,0,0,0) [intercept=True]; AIC=1428.386, BIC=1433.841, Time=0.013 seconds
# Fit ARIMA(1,2,0)x(0,0,0,0) [intercept=True]; AIC=1412.073, BIC=1420.255, Time=0.056 seconds
# Fit ARIMA(0,2,1)x(0,0,0,0) [intercept=True]; AIC=1356.114, BIC=1364.296, Time=0.047 seconds
# Near non-invertible roots for order (0, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA(0,2,0)x(0,0,0,0) [intercept=False]; AIC=1426.389, BIC=1429.116, Time=0.009 seconds
# Fit ARIMA(2,2,0)x(0,0,0,0) [intercept=True]; AIC=1388.525, BIC=1399.435, Time=0.078 seconds
# Fit ARIMA(3,2,0)x(0,0,0,0) [intercept=True]; AIC=1370.911, BIC=1384.548, Time=0.120 seconds
# Fit ARIMA(4,2,0)x(0,0,0,0) [intercept=True]; AIC=1369.042, BIC=1385.406, Time=0.154 seconds
# Fit ARIMA(4,2,1)x(0,0,0,0) [intercept=True]; AIC=1352.733, BIC=1371.825, Time=0.269 seconds
# Fit ARIMA(3,2,1)x(0,0,0,0) [intercept=True]; AIC=1350.754, BIC=1367.119, Time=0.210 seconds
# Fit ARIMA(2,2,1)x(0,0,0,0) [intercept=True]; AIC=1350.805, BIC=1364.442, Time=0.181 seconds
# Fit ARIMA(3,2,2)x(0,0,0,0) [intercept=True]; AIC=1351.138, BIC=1370.230, Time=0.290 seconds
# Fit ARIMA(2,2,2)x(0,0,0,0) [intercept=True]; AIC=1349.173, BIC=1365.538, Time=0.324 seconds
# Fit ARIMA(1,2,2)x(0,0,0,0) [intercept=True]; AIC=1359.298, BIC=1372.935, Time=0.315 seconds
# Near non-invertible roots for order (1, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,2,3)x(0,0,0,0) [intercept=True]; AIC=1356.680, BIC=1375.772, Time=0.514 seconds
# Fit ARIMA(1,2,1)x(0,0,0,0) [intercept=True]; AIC=1358.104, BIC=1369.014, Time=0.158 seconds
# Near non-invertible roots for order (1, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(1,2,3)x(0,0,0,0) [intercept=True]; AIC=1348.909, BIC=1365.274, Time=0.328 seconds
# Near non-invertible roots for order (1, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(3,2,3)x(0,0,0,0) [intercept=True]; AIC=1351.935, BIC=1373.754, Time=0.574 seconds
# Total fit time: 3.653 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  115
# Model:               SARIMAX(1, 2, 3)   Log Likelihood                -668.455
# Date:                Thu, 16 Jul 2020   AIC                           1348.909
# Time:                        00:52:47   BIC                           1365.274
# Sample:                             0   HQIC                          1355.550
#                                 - 115
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.6198      1.236      0.501      0.616      -1.803       3.043
# ar.L1          0.4092      0.114      3.603      0.000       0.187       0.632
# ma.L1         -1.5474      0.638     -2.427      0.015      -2.797      -0.298
# ma.L2          0.3246      0.489      0.664      0.507      -0.634       1.283
# ma.L3          0.3541      0.231      1.533      0.125      -0.099       0.807
# sigma2      7509.4212   4909.358      1.530      0.126   -2112.744    1.71e+04
# ===================================================================================
# Ljung-Box (Q):                       44.37   Jarque-Bera (JB):                78.78
# Prob(Q):                              0.29   Prob(JB):                         0.00
# Heteroskedasticity (H):             220.70   Skew:                             0.77
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train = df.iloc[:104]
test = df.iloc[104:111]

# %%
# from statsmodels.tsa.arima_model import ARMA,ARMAResults,ARIMA,ARIMAResults
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# model = ARIMA(train[para],order=(1, 2, 3))
model = SARIMAX(train[para],order=(1, 2, 3),seasonal_order=(1,2,3,15))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Confirmed   No. Observations:                  104
# Model:             SARIMAX(1, 2, 3)x(1, 2, 3, 15)   Log Likelihood                -429.617
# Date:                            Thu, 16 Jul 2020   AIC                            877.234
# Time:                                    00:53:00   BIC                            897.724
# Sample:                                03-14-2020   HQIC                           885.391
#                                      - 06-25-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5068      0.381      1.329      0.184      -0.241       1.254
# ma.L1         -2.1834      0.938     -2.328      0.020      -4.022      -0.345
# ma.L2          1.7395      1.164      1.494      0.135      -0.543       4.022
# ma.L3         -0.5525      0.532     -1.038      0.299      -1.596       0.491
# ar.S.L15       0.5687    106.866      0.005      0.996    -208.885     210.022
# ma.S.L15      -1.7828     82.711     -0.022      0.983    -163.893     160.328
# ma.S.L30       0.8621    119.496      0.007      0.994    -233.347     235.071
# ma.S.L45      -0.0138     10.404     -0.001      0.999     -20.405      20.377
# sigma2      5230.4047   1.26e+05      0.041      0.967   -2.42e+05    2.52e+05
# ===================================================================================
# Ljung-Box (Q):                       25.97   Jarque-Bera (JB):                15.83
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              56.06   Skew:                            -0.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Obtain predicted values
# start=len(train)
# end=len(train)+len(test)-1

start=104
end=110

# predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('ARIMA(2,2,1) Predictions')
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('SARIMAX(1,2,3,15) Predictions')

# df['forecast'] = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('ARIMA(2,2,1) Predictions')

# %%
# Obtain predicted values
ax = test[para].plot(legend=True,figsize=(12,6))
predictions.plot(legend=True)
# df['forecast'].plot(legend=True)
ax.autoscale(axis='x',tight=True)

# %%
# # from statsmodels.tools.eval_measures import rmse
# from statsmodels.tools.eval_measures import mse

# error = mse(test[para], predictions)
# # print(f'ARIMA(2,2,1) RMSE Error: {error:11.10}')
# # print(f'ARIMA(2,2,1) MSE Error: {error:11.10}')
# print(f'SARIMAX(2,2,1,3) MSE Error: {error:11.10}')

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(test[para], predictions)
MAE
# Out:
# 445.6777719903383

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# per_MAPE = (MAPE/sum(test[para]))*100
per_MAPE = mean_absolute_percentage_error(test[para], predictions)
print(per_MAPE,'%')
# Out:
# 37.2818266094002 %

# %%
type(predictions)
# Out:
# pandas.core.series.Series

# %%
df['forecast'] = predictions
df
# Out:
#             Confirmed  Recovered  Deceased     d1    forecast
# Date
# 2020-03-14          6          0         1    NaN         NaN
# 2020-03-15          0          0         0    NaN         NaN
# 2020-03-16          1          0         0    7.0         NaN
# 2020-03-17          2          0         0    0.0         NaN
# 2020-03-18          5          0         0    2.0         NaN
# ...               ...        ...       ...    ...         ...
# 2020-07-02       1502        271        19  -95.0  686.556282
# 2020-07-03       1694        471        21  -38.0         NaN
# 2020-07-04       1839        439        42  -47.0         NaN
# 2020-07-05       1925        603        37  -59.0         NaN
# 2020-07-06       1843        680        30 -168.0         NaN
#
# [115 rows x 5 columns]

# %%
dictt = {f'{para}':test[para],f'Predicted_{para}':predictions}
dictt
# Out:
# {'Confirmed': Date
#  2020-06-26     445
#  2020-06-27     918
#  2020-06-28    1267
#  2020-06-29    1105
#  2020-06-30     947
#  2020-07-01    1272
#  2020-07-02    1502
#  Freq: D, Name: Confirmed, dtype: int64,
#  'Predicted_Confirmed': 2020-06-26    441.549726
#  2020-06-27    577.577300
#  2020-06-28    676.786800
#  2020-06-29    569.298222
#  2020-06-30    644.772921
#  2020-07-01    739.714345
#  2020-07-02    686.556282
#  Freq: D, Name: SARIMAX(1,2,3,15) Predictions, dtype: float64}

# %%
predicted_df = pd.DataFrame(dictt)
predicted_df
# Out:
#             Confirmed  Predicted_Confirmed
# Date
# 2020-06-26        445           441.549726
# 2020-06-27        918           577.577300
# 2020-06-28       1267           676.786800
# 2020-06-29       1105           569.298222
# 2020-06-30        947           644.772921
# 2020-07-01       1272           739.714345
# 2020-07-02       1502           686.556282

# %%
predicted_df.to_csv('Predicted_KA.csv')
# predicted_csv = pd.read_csv('Predicted_KA.csv')

# predicted_csv.Date = pd.to_datetime(predicted_csv.Date)
# predicted_csv.set_index('Date', inplace=True)
# predicted_csv.index.freq = 'D'
# # print(predicted_csv)
# # predicted_csv = pd.concat([predicted_csv,predicted_df],axis=1,ignore_index=True)
# predicted_csv = pd.merge(predicted_csv, predicted_df, left_index=True, right_index=True, how='outer')
# # predicted_csv = predicted_csv.join(predicted_df, how='outer')
# print(predicted_csv)
# predicted_csv.to_csv('Predicted_KA.csv')

# %%
from pandas.tseries.offsets import DateOffset
import datetime
future_dates=[datetime.datetime(2020, 7, 7)+ DateOffset(n=x)for x in range(0,25)]

# %%
future_datest_df=pd.DataFrame(index=future_dates,columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Confirmed Recovered Deceased   d1 forecast
# 2020-07-27       NaN       NaN      NaN  NaN      NaN
# 2020-07-28       NaN       NaN      NaN  NaN      NaN
# 2020-07-29       NaN       NaN      NaN  NaN      NaN
# 2020-07-30       NaN       NaN      NaN  NaN      NaN
# 2020-07-31       NaN       NaN      NaN  NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])
future_df = future_df.drop("d1", axis=1)
future_df
# Out:
#            Confirmed Recovered Deceased  forecast
# 2020-03-14         6         0        1       NaN
# 2020-03-15         0         0        0       NaN
# 2020-03-16         1         0        0       NaN
# 2020-03-17         2         0        0       NaN
# 2020-03-18         5         0        0       NaN
# ...              ...       ...      ...       ...
# 2020-07-27       NaN       NaN      NaN       NaN
# 2020-07-28       NaN       NaN      NaN       NaN
# 2020-07-29       NaN       NaN      NaN       NaN
# 2020-07-30       NaN       NaN      NaN       NaN
# 2020-07-31       NaN       NaN      NaN       NaN
#
# [140 rows x 4 columns]

# %%
future_df[[para, 'forecast']]
# Out:
#            Confirmed  forecast
# 2020-03-14         6       NaN
# 2020-03-15         0       NaN
# 2020-03-16         1       NaN
# 2020-03-17         2       NaN
# 2020-03-18         5       NaN
# ...              ...       ...
# 2020-07-27       NaN       NaN
# 2020-07-28       NaN       NaN
# 2020-07-29       NaN       NaN
# 2020-07-30       NaN       NaN
# 2020-07-31       NaN       NaN
#
# [140 rows x 2 columns]

# %%
# future_df['forecast'] = results.predict(start = 115, end = 139, dynamic= True)
future_pred = results.predict(start=115, end=139, dynamic=False, typ='levels')

# %%
future_df['forecast'] = future_pred

# %%
future_df[[para, 'forecast']].plot(figsize=(12, 8))

# %%
dicttt = {f'Future_Predicted_{para}':future_pred}
dicttt
# Out:
# {'Future_Predicted_Confirmed': 2020-07-07     777.893070
#  2020-07-08     858.027548
#  2020-07-09     914.820825
#  2020-07-10     959.682850
#  2020-07-11     991.502909
#  2020-07-12    1137.802459
#  2020-07-13    1260.445546
#  2020-07-14    1150.246867
#  2020-07-15    1251.140302
#  2020-07-16    1352.613544
#  2020-07-17    1329.105982
#  2020-07-18    1339.255819
#  2020-07-19    1468.966551
#  2020-07-20    1648.117080
#  2020-07-21    1671.468009
#  2020-07-22    1478.135954
#  2020-07-23    1574.182659
#  2020-07-24    1633.231889
#  2020-07-25    1688.412237
#  2020-07-26    1743.733737
#  2020-07-27    1914.020344
#  2020-07-28    2064.111716
#  2020-07-29    1949.358418
#  2020-07-30    2076.861685
#  2020-07-31    2195.557598
#  Freq: D, dtype: float64}

# %%
future_predicted_df = pd.DataFrame(dicttt)
future_predicted_df
# Out:
#             Future_Predicted_Confirmed
# 2020-07-07                  777.893070
# 2020-07-08                  858.027548
# 2020-07-09                  914.820825
# 2020-07-10                  959.682850
# 2020-07-11                  991.502909
# 2020-07-12                 1137.802459
# 2020-07-13                 1260.445546
# 2020-07-14                 1150.246867
# 2020-07-15                 1251.140302
# 2020-07-16                 1352.613544
# 2020-07-17                 1329.105982
# 2020-07-18                 1339.255819
# 2020-07-19                 1468.966551
# 2020-07-20                 1648.117080
# 2020-07-21                 1671.468009
# 2020-07-22                 1478.135954
# 2020-07-23                 1574.182659
# 2020-07-24                 1633.231889
# 2020-07-25                 1688.412237
# 2020-07-26                 1743.733737
# 2020-07-27                 1914.020344
# 2020-07-28                 2064.111716
# 2020-07-29                 1949.358418
# 2020-07-30                 2076.861685
# 2020-07-31                 2195.557598

# %%
future_predicted_df.index.names = ['Date']
future_predicted_df.index.freq = 'D'
future_predicted_df.to_csv('Future_Predicted_KA.csv')

# future_predicted_csv = pd.read_csv('Future_Predicted_KA.csv')

# future_predicted_csv.Date = pd.to_datetime(future_predicted_csv.Date)
# future_predicted_csv.set_index('Date', inplace=True)
# future_predicted_csv.index.freq = 'D'
# # print(future_predicted_csv)
# # future_predicted_csv = pd.concat([future_predicted_csv,future_predicted_df],axis=1,ignore_index=True)
# future_predicted_csv = pd.merge(future_predicted_csv, future_predicted_df, left_index=True, right_index=True, how='outer')
# # predicted_csv = predicted_csv.join(predicted_df, how='outer')
# print(future_predicted_csv)
# future_predicted_csv.to_csv('Future_Predicted_KA.csv')
